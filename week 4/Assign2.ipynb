# %%
hrs = int(input("Enter Hours:")) #Integer input
rate = float(input("Enter Rate:")) #Float input
thepay = rate*hrs
thepaystr = str(thepay) # Type conversion
print("Pay: " + thepaystr) # Printing the result.
# Out:
# Enter Hours: 35
# Enter Rate: 2.75
# Pay: 96.25
